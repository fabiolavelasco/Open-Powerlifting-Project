# %%
import pandas as pd

# %%
df_pl = pd.read_csv('openpowerlifting-latest/openpowerlifting-2021-11-03/openpowerlifting-2021-11-03-c500d80d.csv')
# Out:
# C:\Users\fivel\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (33,35,38) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_pl
# Out:
#                            Name Sex Event   Equipment   Age AgeClass  \
# 0                   Alona Vladi   F   SBD         Raw  33.0    24-34
# 1            Galina Solovyanova   F   SBD         Raw  43.0    40-44
# 2                Daniil Voronin   M   SBD         Raw  15.5    16-17
# 3                Aleksey Krasov   M   SBD         Raw  35.0    35-39
# 4        Margarita Pleschenkova   M   SBD         Raw  26.5    24-34
# ...                         ...  ..   ...         ...   ...      ...
# 2550651            Inna Orobets   F   SBD  Single-ply  45.0    45-49
# 2550652             Ágnes Szabó   F   SBD  Single-ply  27.5    24-34
# 2550653   Brenda van der Meulen   F   SBD  Single-ply  37.5    35-39
# 2550654            Kelly Phasey   F   SBD  Single-ply  39.5    35-39
# 2550655  Hildeborg Juvet Hugdal   F   SBD  Single-ply  32.5    24-34
#
#         BirthYearClass Division  BodyweightKg WeightClassKg  ...  Tested  \
# ...

# %%
small_pl = df_pl[['Name','Age', 'Sex', 'BodyweightKg', 'TotalKg', 'Country']].copy()
small_pl.head(40)
# Out:
#                        Name   Age Sex  BodyweightKg  TotalKg Country
# 0               Alona Vladi  33.0   F         58.30    247.5  Russia
# 1        Galina Solovyanova  43.0   F         73.10    282.5  Russia
# 2            Daniil Voronin  15.5   M         67.40    267.5  Russia
# 3            Aleksey Krasov  35.0   M         66.65    430.0  Russia
# 4    Margarita Pleschenkova  26.5   M         72.45    265.0  Russia
# 5         Sergey Timoshenko  15.5   M         78.80    275.0  Russia
# 6         Vladimir Karavaev  57.5   M         79.65    335.0  Russia
# 7          Tatyana Altunina  26.0   F         96.50    287.5  Russia
# 8            Ruslan Gasanov  31.5   M        102.55    652.5  Russia
# 9        Ekaterina Glukhova  25.5   F         54.80    212.5  Russia
# 10          Ruslan Gurbatov  25.5   M         73.05    397.5  Russia
# 11           Denis Balotvin  25.5   M         94.75    585.0  Russia
# 12           Yuriy Solovyev  26.5   M         98.90    585.0  Russia
# ...

# %%
pl_USA = small_pl[small_pl['Country'] == 'USA']
pl_USA.head(40)
# Out:
#                           Name   Age Sex  BodyweightKg  TotalKg Country
# 698             Daniel Ramires  27.0   M         67.50    500.0     USA
# 2390            Jesus Martinez   NaN   M         87.50    677.5     USA
# 2600                Jose Ramos   NaN   M         88.30    547.5     USA
# 2693            João Gonçalves  24.5   M         88.60      NaN     USA
# 5062              Jason Taylor   NaN   M         79.40    110.0     USA
# 5071            Michael Watson   NaN   M        125.00    617.5     USA
# 5114              Dillon Smith   NaN   M        110.00    422.5     USA
# 5116             Luke Reynolds   NaN   M        140.00    410.0     USA
# 5216         Andrew Fitzgerald  22.0   M         94.40    635.0     USA
# 5280             Jasmine Scott  28.0   F         66.70    267.5     USA
# 5294                Casey Carr  30.0   F         96.15      NaN     USA
# 5307               David Bauer  20.0   M         88.85    575.0     USA
# ...

# %%
pl_USA.sort_values(by='TotalKg', ascending=False)
pl_USA.head(40)
# Out:
#                        Name   Age Sex  BodyweightKg  TotalKg Country
# 958981            Dave Hoff  31.0   M        132.60  1407.50     USA
# 977308            Dave Hoff  30.0   M        133.20  1367.50     USA
# 809144            Dave Hoff  29.0   M        131.09  1365.31     USA
# 812186            Dave Hoff  25.0   M        122.97  1363.05     USA
# 1442659  Donnie Thompson #1  46.5   M        174.69  1360.78     USA
# 985818            Dave Hoff  32.0   M        135.70  1345.00     USA
# 811821            Dave Hoff  28.5   M        129.27  1344.90     USA
# 1442941           Dave Hoff  23.5   M        126.55  1342.63     USA
# 1444874           Dave Hoff  25.0   M        123.79  1342.63     USA
# 951721            Dave Hoff  24.0   M        124.80  1325.00     USA
# 996730            Dave Hoff  30.5   M        134.35  1325.00     USA
# 811866            Dave Hoff  26.0   M        126.19  1324.49     USA
# 1441536           Dave Hoff  24.0   M        124.83  1322.22     USA
# ...

# %%
pl_USA.dropna()
# Out:
#                        Name   Age Sex  BodyweightKg  TotalKg Country
# 958981            Dave Hoff  31.0   M        132.60  1407.50     USA
# 977308            Dave Hoff  30.0   M        133.20  1367.50     USA
# 809144            Dave Hoff  29.0   M        131.09  1365.31     USA
# 812186            Dave Hoff  25.0   M        122.97  1363.05     USA
# 1442659  Donnie Thompson #1  46.5   M        174.69  1360.78     USA
# ...                     ...   ...  ..           ...      ...     ...
# 974107             Eli Pyne   6.0   M         16.50    10.00     USA
# 1930146       Kayla Abusham  15.0   F         56.00    10.00     USA
# 2006345           Alex Hill   6.0   F         64.00    10.00     USA
# 1939954         Edith Cohen   6.0   F         21.77     7.50     USA
# 1939983        Austin Amend   6.0   M         21.77     5.00     USA
#
# [447516 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(x='BodyweightKg', y='TotalKg', data=pl_USA)
# Out:
# <AxesSubplot:xlabel='BodyweightKg', ylabel='TotalKg'>

# %%
pl_USAtop.isnull().sum()
# Out:
# Name              0
# Age             105
# Sex               0
# BodyweightKg     66
# TotalKg           0
# Country           0
# dtype: int64

# %%
pl_USA.dropna()
# Out:
#                        Name   Age Sex  BodyweightKg  TotalKg Country
# 958981            Dave Hoff  31.0   M        132.60  1407.50     USA
# 977308            Dave Hoff  30.0   M        133.20  1367.50     USA
# 809144            Dave Hoff  29.0   M        131.09  1365.31     USA
# 812186            Dave Hoff  25.0   M        122.97  1363.05     USA
# 1442659  Donnie Thompson #1  46.5   M        174.69  1360.78     USA
# ...                     ...   ...  ..           ...      ...     ...
# 974107             Eli Pyne   6.0   M         16.50    10.00     USA
# 1930146       Kayla Abusham  15.0   F         56.00    10.00     USA
# 2006345           Alex Hill   6.0   F         64.00    10.00     USA
# 1939954         Edith Cohen   6.0   F         21.77     7.50     USA
# 1939983        Austin Amend   6.0   M         21.77     5.00     USA
#
# [447516 rows x 6 columns]

# %%
import scipy.stats as st

r, p_val = st.pearsonr(pl_USA['BodyweightKg'], pl_USA['TotalKg'])
print(r)
print(p_val)
# Out:
# 0.3855762462398117
# 0.0

# %%
from statsmodels.formula.api import ols 

model = ols("TotalKg ~ BodyweightKg", data = pl_USA).fit()

model.params
# Out:
# Intercept       125.846759
# BodyweightKg      3.367749
# dtype: float64

# %%
sns.lmplot(x='BodyweightKg', y='TotalKg', data=pl_USA, ci = None)

# %%
sns.lmplot(x='Age', y='TotalKg', data=pl_USAtop, ci = None)
